# %%
import iplantuml

# %%
# %%plantuml
#
# @startuml
#     class Players
#     {
#         # string[] playerNames
#         # char p1Icon
#         .. Constructor(s) ..
#         + Players()
#         .. Setters ..
#         + SetPlayerName(string playerName,
#                         int sel)
#         + SetPlayerIcon(char p1Icon)
#         .. Getter(s) ..
#         + GetPlayerName(int sel)
#         + GetPlayerIcon(int sel)
#
#         .. Method(s) ..
#         - CheckPlayerIcon(char icon)
#     }
#
#     class Grid
#     {
#         # Players players
#         # char[][] grid
#
#         .. Constructor(s) ..
#         + Grid(ref Players players)
#         + Grid(ref Players players, int xSize,
#                int ySize = -1, char gridIcon = '.')
#         .. Getter(s) ..
#         + char GetGridIcon()
#         + char[][] GetGrid()
#         + int GetXSize()
#         + int GetYSize()
#         + string OutputGrid()
#         .. Method(s) ..
#         + void DrawGrid()
#         + void ClearGrid()
#         + void MakeMove(int playerIndex, int y)
#
#         - bool CheckMove(ref int x, int y)
#         - bool CheckSizes(int x, ref int y)
#         - bool CheckIcon(char gridIcon)
#         - void InitialiseGrid()
#     }
#
#     class GameStatus
#     {
#         # Players players
#         # char[] playerIcons
#         # Grid grid
#         # int winnerIndex
#         .. Constructor(s) ..
#         + GameStatus(ref Players players,
#                      ref Grid grid)
#         .. Getters(s) ..
#         + bool GetGameStatus()
#         + int GetWinner()
#         .. Method(s) ..
#         - int CheckGame()
#     }
#
#     Players -> Grid : ref
#     Players -> GameStatus : ref
#     Grid -> GameStatus : ref
#
# @enduml

# %% [markdown]
# # CRC Layout
# class ClassName
# {
#     Responsibilities : Collaborators
# }
#
# ![image.png](attachment:image.png)

# %%
# %%plantuml
#
# @startuml
#
#     class Players
#     {
#         Store player names : Players
#         Store player one icon : Players
#         Edit player name : Players
#         Edit player icon : Players
#     }
#
#     class Grid
#     {
#         Set grid icon : Grid
#         Initialise grid : Grid
#         Make move : Grid, Player
#         Check valid move : Grid, Player
#     }
#
#     class GameStatus
#     {
#         Check gamestatus : Grid
#         Get the winner : Player
#     }
# @enduml
